# %% [markdown]
# ### Instrucciones
# 1. Cada sección presenta un ejercicio con un enfoque único y un conjunto de datos específico.
# 2. Documente cada paso de implementación y justifique sus resultados con el análisis correspondiente.
# 3. El documento debe entregarse ejecutado y cada resultado debe contener comentarios. En caso de falta de comentario sobre algún resultado este no será considerado para la calificación.
# 4. Recuerde que los puntos a realizar tienen el mismo peso en la nota.
#
#
#
# ### Sección 1
#
# #### Ejercicio 1: Segmentación de Empresas con K-means y DBSCAN
# - **Dataset**: [Companies Bankruptcy Prediction](https://archive.ics.uci.edu/ml/datasets/Polish+companies+bankruptcy+data) (datos financieros de empresas polacas). Use el siguiente código para cargar la base de datos, es recomendado que visite el link para que entienda el significado de las variables.
#
#
# ```
# !pip install ucimlrepo
# from ucimlrepo import fetch_ucirepo
#
# # fetch dataset
# polish_companies_bankruptcy = fetch_ucirepo(id=365)
#
# # data (as pandas dataframes)
# X = polish_companies_bankruptcy.data.features
# y = polish_companies_bankruptcy.data.targets
#
# # metadata
# print(polish_companies_bankruptcy.metadata)
#
# # variable information
# print(polish_companies_bankruptcy.variables)
#
#
# ```
#
#
#
# - **Objetivo**: Clasificar empresas según características financieras para identificar patrones en su perfil de riesgo.
#
# 1. **Preprocesamiento**:
#    - Cargue los datos y elimine registros con valores faltantes.
#    - Seleccione un conjunto de 8 variables financieras (ej.: ingresos, gastos, activos) que puedan representar el perfil de riesgo de una empresa. Visite el link para que pueda observar el nombre de las variables a elegir con base en su significado.
#    - No use la variable
#
# 2. **Clustering con K-means**:
#    - Estandarice las variables seleccionadas.
#    - Determine el número óptimo de clusters usando el método del codo y luego aplique K-means.
#    - Describa y caracterice cada grupo de empresas.
#    - Identifique si alguno de los grupos coincide con la clase (variable y).
#
# 3. **Clustering aglomerado**:
#    - Ajuste el número de clusters y la métrica de distancia y realice el clustering.
#    - Describa y caracterice cada grupo de empresas.
#    - Identifique si alguno de los grupos coincide con la clase (variable y).
#
# 4. **Análisis**:
#    - Compare los resultados obtenidos por cada técnica, discutiendo las diferencias encontradas.
#
# ---
#
# ### Sección 2: Reducción de Dimensionalidad
#
# #### Ejercicio 2: Análisis de Factores en la Productividad Laboral
# - **Dataset**: Use la base de datos `Employees_final_dataset.csv`
# - **Objetivo**: Utilizar técnicas de reducción de dimensionalidad para entender los factores clave que explican la productividad de los empleados.
#
# 1. **Carga y Exploración de Datos**:
#    - Cargue el dataset y examine las variables disponibles.
#    - realice análisis exploratorio y la tareas de preprocesamiento que observe nacesarias como imputación, estandarización u otras.
#
# 2. **Reducción de Dimensionalidad con PCA**:
#    - Aplique PCA para reducir las dimensiones del dataset y retenga solo los componentes que explican al menos el 85% de la varianza.
#    - Interprete las principales variables asociadas a cada componente.
#
# 3. **Reducción de Dimensionalidad UMAP y t-sne**:
#    - Aplique UMAP y t-SNE con distintos hiperparámetros de manera que pueda visualizar los datos en dos dimensiones.
#    - Compare y discuta las diferencias entre los resultados, observa algun hallazgo interesante?.
#
#
# ---
#
# ### Sección 3: Detección de Anomalías en Datos Médicos
#
# #### Ejercicio 3: Identificación de Anomalías en Datos de Pacientes con Condiciones de Tiroides
# - **Dataset**: `hypothyroid.csv` (datos de pacientes con características médicas relevantes para el diagnóstico de tiroides).
# - **Objetivo**: Detectar patrones inusuales que puedan representar diagnósticos o condiciones atípicas en pacientes.
#
# 1. **Preprocesamiento**:
#    - Limpie el dataset transformando las variables categóricas a valores numéricos, y trate los valores faltantes según corresponda.
#    - Seleccione las variables que sean relevantes para el análisis de condiciones de tiroides y normalice las variables continuas para mejorar el rendimiento de los algoritmos de detección de anomalías.
#
# 2. **Aplicación de Algoritmos de Detección de Anomalías**:
#    - Implemente y compare los siguientes algoritmos para la detección de anomalías en el dataset:
#      - **Isolation Forest**
#      - **One-Class SVM**
#      - **Local Outlier Factor (LOF)**
#      - **Elliptic Envelope**
#    - Para cada algoritmo:
#      - Ajuste los parámetros principales y registre la proporción de puntos detectados como anómalos.
#      - Evalúe el rendimiento de cada modelo usando métricas de precisión, sensibilidad y especificidad con respecto a la columna `binaryClass`.
#
# 3. **Reducción de Dimensionalidad con UMAP**:
#    - Aplique **UMAP** para reducir la dimensionalidad del dataset a 2 dimensiones, manteniendo la estructura de vecinos en el espacio de alta dimensión.
#    - Visualice los datos reducidos, coloreando los puntos según la detección de anomalías de cada algoritmo. Esto permite observar patrones o agrupaciones en los datos transformados que correspondan a anomalías o condiciones particulares.
#
# 4. **Aplicación de Algoritmos en Datos Reducidos**:
#    - Aplique nuevamente los algoritmos de **Isolation Forest**, y **LOF** sobre los datos transformados por UMAP.
#    - Compare los resultados de detección en el espacio reducido frente al espacio original en términos de sensibilidad y especificidad.
