# %% [markdown]
# # Ejercicio: Clasificación Binaria con Estrategias de Muestreo para Manejar el Desbalanceo de Clases
#
# ## Objetivo
#
# El objetivo de este ejercicio es:
#
# 1. Generar un conjunto de datos sintético para un problema de clasificación binaria con clases desbalanceadas.
# 2. Aplicar diferentes estrategias de muestreo para equilibrar las clases.
# 3. Entrenar modelos de regresión logística sin regularización en cada conjunto de datos muestreado.
# 4. Evaluar y comparar el desempeño de los modelos utilizando diversas métricas.
#
# ## Instrucciones
#
# ### 1. Generación del Conjunto de Datos
#
# - Utiliza `make_classification` de `sklearn.datasets` para crear un conjunto de datos sintético con 10,000 muestras y 20 características.
# - Configura el conjunto de datos para que 95% de las muestras pertenezcan a la clase 0 y 5% a la clase 1, introduciendo un desequilibrio significativo.
#
# **Este punto no debes hacerlo**, eso sí, la base de datos resultante es la que debes usar para los demás puntos.

# %%
# Importación de Librerías
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, classification_report, roc_curve


from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler, SMOTE

# 1. Generación del Conjunto de Datos
X, y = make_classification(n_samples=10000,
                           n_features=20,
                           n_informative=2,
                           n_redundant=10,
                           n_clusters_per_class=1,
                           weights=[0.95, 0.05],
                           flip_y=0,
                           random_state=42)

# Convertir a DataFrame para facilitar la manipulación
feature_names = [f'feature_{i}' for i in range(1, 21)]
df = pd.DataFrame(X, columns=feature_names)
df['target'] = y

# %%
df.head()
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0   0.477908  -0.913100  -0.142257  -0.888393   0.101232   0.557124
# 1  -0.307475  -0.097225   0.936320   0.642466   1.165698  -0.399368
# 2   1.047926   1.403379  -0.488940  -1.913669  -0.082735   1.201800
# 3  -0.249407  -0.431734   1.639818   0.195003   1.070736  -0.135673
# 4   0.049466   0.530635  -2.463684  -0.006239   0.735609   0.008183
#
#    feature_7  feature_8  feature_9  feature_10  ...  feature_12  feature_13  \
# 0   0.603857   0.392627  -0.068788   -0.421507  ...   -0.151552    0.489513
# 1  -0.304983  -0.322777   0.028461    0.188398  ...    0.213513   -0.299423
# 2   1.364556   2.394906  -0.158484   -0.964356  ...   -0.276121    1.080888
# 3  -0.631617   0.082602   0.095749    0.533669  ...   -0.360470   -0.314264
# 4   0.163489   1.181896  -0.026218   -0.143726  ...    0.124572    0.069430
#
#    feature_14  feature_15  feature_16  feature_17  feature_18  feature_19  \
# ...

# %%
df.isna().sum()
# Out:
# feature_1     0
# feature_2     0
# feature_3     0
# feature_4     0
# feature_5     0
# feature_6     0
# feature_7     0
# feature_8     0
# feature_9     0
# feature_10    0
# feature_11    0
# feature_12    0
# feature_13    0
# feature_14    0
# feature_15    0
# feature_16    0
# feature_17    0
# feature_18    0
# feature_19    0
# feature_20    0
# target        0
# dtype: int64

# %% [markdown]
# ### 2. Análisis Exploratorio de Datos (EDA)
#
# - Visualiza la distribución de clases para confirmar el desbalanceo.
# - Describe las características numéricas y categóricas (si las hubiera).
#
# ### 3. División del Conjunto de Datos
#
# - Divide el conjunto de datos en conjuntos de entrenamiento y prueba con una proporción de 80-20, manteniendo la estratificación para preservar la distribución de clases.
#
# ### 4. Estrategias de Muestreo
#
# Aplica las siguientes técnicas para manejar el desbalanceo de clases en el conjunto de entrenamiento:
#
# 1. **Línea Base (Baseline)**: Sin aplicar ninguna técnica de muestreo.
# 2. **Submuestreo Aleatorio (Random Undersampling)**: Reducir el número de muestras de la clase mayoritaria. Aquí te dejo un código de ayuda:
#
# ```python
#   rus = RandomUnderSampler(random_state=42)
#   X_train_rus, y_train_rus = rus.fit_resample(X_train, y_train)
# ```
# Puedes intentar cualquier otro que encuentres en la librería [imbalance learn](https://imbalanced-learn.org/stable/)
#
# 3. **Sobremuestreo Aleatorio (Random Oversampling)**: Aumentar el número de muestras de la clase minoritaria. Aquí te dejo un código de ayuda:
#
# ```python
#   ros = RandomOverSampler(random_state=42)
#   X_train_ros, y_train_ros = ros.fit_resample(X_train, y_train)
#
# ```
#
# Puedes intentar cualquier otro que encuentres en la librería [imbalance learn](https://imbalanced-learn.org/stable/)
#
# 4. **SMOTE (Synthetic Minority Over-sampling Technique)**: Generar muestras sintéticas para la clase minoritaria.
#
# ### 5. Entrenamiento de Modelos
#
# - Para cada estrategia de muestreo, entrena un modelo de regresión logística.
# - Asegúrate de estandarizar las características antes de entrenar el modelo.
#
# ### 6. Evaluación de Modelos
#
# - Evalúa cada modelo utilizando las siguientes métricas en el conjunto de prueba:
#   - Exactitud (Accuracy)
#   - Precisión (Precision)
#   - Recall (Sensibilidad)
#   - F1-score
#   - AUC-ROC
# - Visualiza la matriz de confusión y la curva ROC para cada modelo.
#
# ### 7. Comparación y Discusión
#
# - Compara el desempeño de los modelos entrenados con diferentes estrategias de muestreo.
# - Discute cuál estrategia de muestreo fue más efectiva para manejar el desbalanceo de clases en este escenario.
