# %% [markdown]
# Con la base de datos de Home Loan por favor realice las siguientes tareas. Para responder las preguntas análiticas por favor visite [kaggle](https://www.kaggle.com/datasets/defcodeking/home-loan-prediction-prepared-datasets?select=test_with_new_features.csv) y aprenda un poco más de las variables.
#
#
#
# 1.   Cargue la base de datos y trabaje con una muestra aleatoria de 10000 datos.
#
# 2.   Realice y explique el comportamiento de los histogramas de las variables numéricas.
#
# 3.  Realice un mapa de calor de las variables numéricas y concluya con respecto a las correlaciones encontradas, cuales son favorables y cuáles no.
#
# 4. Realice gráficos de barras de las variables categóricas (intente hacer un ciclo para realizar este gráfico)
#
# 5. Identifique observando el resumen descriptivo, la cantidad de datos nulos, duplicados, y los gráficos de arriba para determinar cuáles cree que son las tareas de preprocesamiento que debe realizar.
#
# 6. Por favor realice una división de la base de datos entre conjunto de entrenamiento y conjunto de testeo, considera que tú y es la variable "target". Dejando un 10% de los datos para testeo.
#
# 7. Si ha detectado en sus pasos anteriores valores faltantes, por favor realice imputaciones univariadas para las variables según sean ellas numéricas o categóricas.
#
# 8. Realiza la estandarización de las variables numéricas usando el método min-máx.
#
# 9. Realiza la transformación de variables categóricas.
#
# 10. Proponga un pipeline que realiza las anteriores de preprocesamiento.
#
# 10. Ahora vas a realizar la selección de 15 variables usando el seleccionador secuencial con el método forward.
#
# 11. Proponga un pipeline donde incluya el creado en el paso 10 y adicionalmente contenga el paso 10 y el entrenamiento de todas las variables seleccionadas.
#
# 11. Con las variables seleccionadas crea 5 modelos de regresión lineal múltiple con las siguientes características:
#
# *  Uno con 8 variables elegidas aleatoriamente.
# *  Uno con las 5 variables con los VIF más bajos.
# *  Uno de regresión polinómica de grado 2 sin interacción.
# * Uno con regresión polinómica de grado 2 con interacción.
#
# 12. Compara los modelos usando los criterios AIC, BIC y $R^2$ ajustado. ¿Con cuál de ellos te quedarías con base en dichos criterios?  cuál es el MSE?
#
# 13. Luego de la clase del martes, haz el análisis del modelo seleccionado observando el comportamiento de los residuos, de la normalidad de los errores, ¿observas algunos atípicos con base en el criterio de la distancia de Cook?
#
# Nota: si algún parámetro es aleatorio usa la semilla 24.
