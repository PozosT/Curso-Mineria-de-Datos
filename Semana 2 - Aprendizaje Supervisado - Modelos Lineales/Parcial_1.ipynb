# %% [markdown]
# ## Base de datos.
#
# Vuestro objetivo es analizar y crear modelos de regresión lineal para predecir el comportamiento de la variable **charges**.
#
#
#
#
#
# Tenga en cuenta la siguiente definición de algunas de las variables:
#
#
# * age: edad del beneficiario principal
#
# * sex: sexo del contratante del seguro, mujer, hombre
#
# * bmi: índice de masa corporal, que proporciona una comprensión del cuerpo, los pesos que son relativamente altos o bajos en relación con la altura,
# índice objetivo de peso corporal (kg / m ^ 2) utilizando la relación entre la altura y el peso, idealmente 18,5 a 24,9
#
# * children	: Número de hijos cubiertos por el seguro de enfermedad / Número de personas a cargo
#
# * smoker: Fumador
#
# * region: la zona de residencia del beneficiario en los EE.UU., noreste, sureste, suroeste, noroeste.
#
# * charges: Gastos médicos individuales facturados por el seguro de enfermedad

# %% [markdown]
# ### Parte 1: Análisis Exploratorio de Datos (EDA)
# 1. **Visualización de datos**:
#    - **Tarea 1**: Crea histogramas o gráficos de densidad para visualizar las distribuciones de las columnas numéricas. Comenta 2 resultados que te llamen la atención.
#    - **Tarea 2**: Utiliza diagramas de caja para visualizar la distribución y los valores atípicos en las columnas numéricas. Comenta  2 resultados que te llamen la atención.
#    - **Tarea 3**: Crea diagrama de barra para las variable categóricas. Comenta  2 resultados que te llamen la atención. Consideras que pueden eliminar algunas de ellas?
#
# 2. **Análisis bivariado**:
#    - **Tarea 4**: Genera un mapa de calor de correlaciones entre todas las variables numéricas.
#    - **Tarea 5**: Detalla en la correlación entre todas las variables y nuestra variable objetivo y determina cual de ellas tienen una relación fuerte o debil. Consideras que pueden eliminar algunas de ellas ?
#    - **Tarea 6**: Detalla en la correlación entre las variables independiente o explicativas. Que variables parecen tener una relación fuerte entre sí? Que problema pueden causar estas correlaciones fuertes en el modelo de regresión?. Cuales variables eliminarías?
#
#
# ### Parte 2: Preprocesamiento de Datos
#
# Nota: Antes de realizar el preprocesamiento divide la base de datos en los conjuntos de entrenamiento y testeo, dejando un 30% de datos para testeo.
#
# 1. **Detección y manejo de valores atípicos**:
#    - **Tarea 1**: Utiliza un método estadístico para identificar los valores atípicos en las columnas numéricas.
#    - **Tarea 2**: Elimina los valores atípicos para las variables elegidas con base en los resultados del punto anterior.
#
# 2. **Tratamiento de valores faltantes**:
#    - **Tarea 3**: Identifica las columnas con valores faltantes y reporta el porcentaje de nulos en cada una.
#    - **Tarea 4**: Aplica la imputación multiple para las variables numéricas.
#    - **Tarea 5**: Para las columnas categóricas, aplica una estrategia de imputación adecuada.
#
# 3. **Normalización y escalado de datos**:
#    - **Tarea 6**: Aplica un escalado estandarizado para las variables númericas.
#
# 4. **Transformación categoricos**:
#    - **Tarea 7**: Aplica codificación One-Hot en las variables categóricas.
#
# 5. **Pipeline**:
#    - **Tarea 8**: Proponga un pipeline que realice las tareas de normalización y escalado anteriores. No lo ejecute, debe dejarlo apenas formulado. Si usó pipelines previamente para los puntos 2 y 3 no debes proponerlo!
#
# ### Parte 3: Modelos de regresión
#
# 1. **Crear modelos de regresión lineal**:
#    - **Tarea 1**: Crear el modelo_1 con 5 variables elegidas por medio del seleccionador secuencial con el  método forward con las base de datos que salga de la parte 2.
#
#    - **Tarea 2**: Crear el modelo_2 con variables que seleccione con base en los resultados de su análisis descritivo inicial en la parte 1.
#
#    - **Tarea 3**: Crear el modelo_3 con variables con todas las varibles.
#
# 2. **Crear modelos de regresión lineal**:
#
#    - **Tarea 4**: Comparar los modelos usando los criterios AIC, BIC y $R^2$ ajustado. ¿Con cuál de ellos te quedarías con base en dichos criterios?  cuál es el MSE del modelo electo? Cuales son los coeficientes del modelo electo?
#
# 3. **Analizar el modelo elegido (Bono)**:
#
#    - **Bono**:  Realiza el análisis del modelo seleccionado observando el comportamiento gráfico de los residuos y comenta si son normales y con varianza igual ¿Hay algo que te llame la atención?
#
#    - **Bono**: Calcula el VIF para el modelo seleccionado y comenta.
#
# **Nota:** usa la semilla 42 y las preguntas que tienen bono elevan la nota si las realizas pero no la disminuye, en caso de no alcanzarlas a realizar.
