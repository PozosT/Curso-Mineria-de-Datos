# %% [markdown]
# En los códigos de más abajo encuentra la base de datos con la que debe trabajar.
#
# ### Instrucciones:
# 1. **Importar librerías y cargar el dataset:**
#    - Cargue las librerías necesarias (pandas, numpy, scikit-learn, matplotlib, seaborn, etc.).
#    - Cargue la base de datos 'MoneyBall' y visualice las primeras filas.
#
# 2. **Análisis exploratorio de datos (EDA):**
#    - Resuma las principales características del conjunto de datos utilizando `.describe()` y `.info()`.
#    - Identifique variables numéricas y categóricas, y resuma el número de observaciones, tipos de datos, valores nulos, etc.
#    - Cree gráficos (histogramas y boxplots) para identificar patrones y outliers en las variables numéricas.
#    - Utilice gráficos de barras para visualizar las distribuciones de al menos dos variables categóricas.
#
# 3. **Preprocesamiento:**
#    - **Manejo de valores nulos:** Identifique qué variables tienen valores faltantes y aplique una estrategia para imputarlos o eliminarlos.
#    - **Transformación de variables categóricas:** Utilice `OneHotEncoder` o `LabelEncoder` para transformar las variables categóricas en variables numéricas.
#    - **Escalamiento de variables numéricas:** Escale las variables numéricas utilizando `StandardScaler` o `MinMaxScaler`.
#
# 4. **Creación de variables polinómicas:**
#    - Utilice `PolynomialFeatures` para crear variables polinómicas de grado 2 para al menos dos de las variables numéricas del dataset.
#    - Analice el impacto de las nuevas variables en la correlación de las variables del conjunto de datos.
#
# 5. **Construcción del modelo de regresión:**
#    - **Separación de datos:** Divida los datos en conjuntos de entrenamiento y prueba (80% entrenamiento, 20% prueba).
#    - **Selección de variables:** Utilice un método de selección de variables como `SelectKBest`u otra de su preferencia para seleccionar las características más importantes para el modelo de regresión.
#    - **Ajuste del modelo:** Entrene un modelo de regresión lineal utilizando el conjunto de entrenamiento y evalúe el desempeño utilizando el conjunto de prueba.
#    - **Evaluación del modelo:** Calcule y reporte el MSE (Mean Squared Error) y \( R^2 \) en el conjunto de prueba.
#
# 6. **Conclusión:**
#    - En un párrafo final, resuma los principales hallazgos del análisis y el modelo de regresión, incluyendo si el modelo ajustado tiene un buen desempeño y qué variables fueron las más importantes.

# %%
# Auto-setup when running on Google Colab
if 'google.colab' in str(get_ipython()):
    # !pip install openml

# General imports
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import openml as oml
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.0/158.0 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 23.5 MB/s eta 0:00:00
# ...
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11717 sha256=9a89360f1f532328c0627c6b4dd98c90f87dd0e6460346c7881c8f7e4917236e
#   Stored in directory: /root/.cache/pip/wheels/5d/2a/9c/3895d9617f8f49a0883ba686326d598e78a1c2f54fe3cae86d
# Successfully built liac-arff
# ...
# WARNING:openml:No permission to create OpenML directory at /root/.config/openml! This can result in OpenML-Python not working properly.

# %%
# Download MoneyBall data from OpenML
moneyball = oml.datasets.get_dataset(41021)
# Get the pandas dataframe (default)
X, y, _, attribute_names = moneyball.get_data(target=moneyball.default_target_attribute)

# %%
# Crear base de datos
df = pd.concat([X, y], axis=1)
